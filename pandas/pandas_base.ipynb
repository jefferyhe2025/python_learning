# %%
import numpy as np
import pandas as pd

from base.practice5 import index

pd.__version__
# Out:
# '2.3.1'

# %% [markdown]
# ## 2.1 文件的读取和写入

# %% [markdown]
# #### 1.文件读取

# %%
# 读取csv文件
df_csv = pd.read_csv("data_base/data/ch2/my_csv.csv")
df_csv
# Out:
#    col1 col2  col3    col4        col5
# 0     2    a   1.4   apple  2020-01-01
# 1     3    b   3.4  banana  2020-01-02
# 2     6    c   2.5  orange  2020-01-05

# %%
# 读取txt文件
df_txt = pd.read_table("data_base/data/ch2/my_table.txt")
df_txt
# Out:
#    col1 col2  col3    col4      col5
# 0     2    a   1.4   apple  2020/1/1
# 1     3    b   3.4  banana  2020/1/2
# 2     6    c   2.5  orange  2020/1/5

# %%
# 读取excel文件
df_excel = pd.read_excel("data_base/data/ch2/my_excel.xlsx")
df_excel
# Out:
#    col1 col2  col3    col4      col5
# 0     2    a   1.4   apple  2020/1/1
# 1     3    b   3.4  banana  2020/1/2
# 2     6    c   2.5  orange  2020/1/5

# %% [markdown]
# ##### 1.1公共参数

# %%
# 公共参数head
df_txt = pd.read_table("data_base/data/ch2/my_table.txt",header=None)
df_txt
# Out:
#    col1 col2  col3    col4      col5
# 0     2    a   1.4   apple  2020/1/1
# 1     3    b   3.4  banana  2020/1/2
# 2     6    c   2.5  orange  2020/1/5

# %%
# 公共参数index_col
df_csv = pd.read_csv("data_base/data/ch2/my_csv.csv",index_col=['col1','col2'])
df_csv
# Out:
#            col3    col4      col5
# col1 col2
# 2    a      1.4   apple  2020/1/1
# 3    b      3.4  banana  2020/1/2
# 6    c      2.5  orange  2020/1/5

# %%
# 公共参数usecols
df_txt = pd.read_table("data_base/data/ch2/my_table.txt",usecols=['col1','col2'])
df_txt
# Out:
#    col1 col2
# 0     2    a
# 1     3    b
# 2     6    c

# %%
# 公共参数parse_dates
df_csv = pd.read_csv("data_base/data/ch2/my_csv.csv",parse_dates=['col5'])
df_csv
# Out:
#    col1 col2  col3    col4       col5
# 0     2    a   1.4   apple 2020-01-01
# 1     3    b   3.4  banana 2020-01-02
# 2     6    c   2.5  orange 2020-01-05

# %%
# 公共参数nrows
df_excel = pd.read_excel("data_base/data/ch2/my_excel.xlsx",nrows=3)
df_excel
# Out:
#    col1 col2  col3    col4      col5
# 0     2    a   1.4   apple  2020/1/1
# 1     3    b   3.4  banana  2020/1/2
# 2     6    c   2.5  orange  2020/1/5

# %% [markdown]
# ##### 1.3 分隔参数

# %%
pd.read_table(
    'data_base/data/ch2/my_table_special_sep.txt',
    sep=r'\|\|\|\|',
    engine='python'
)
# Out:
#   col1                 col2
# 0   TS    This is an apple.
# 1   GQ      My name is Bob.
# 2   WT           Well done!

# %% [markdown]
# #### 2.2数据写入

# %%
# 去除索引
df_csv.to_csv('data_base/data/ch2/my_csv_saved.csv',index=False)
print(open('data_base/data/ch2/my_csv_saved.csv').read())
# Out:
# col1,col2,col3,col4,col5
# 2,a,1.4,apple,2020-01-01
# 3,b,3.4,banana,2020-01-02
# 6,c,2.5,orange,2020-01-05

# %%
# 制表
df_txt.to_csv('data_base/data/ch2/my_txt_saved.txt',sep='\t',index=False)
print(open('data_base/data/ch2/my_txt_saved.txt').read())
# Out:
# col1	col2	col3	col4	col5
# 2	a	1.4	apple	2020/1/1
# 3	b	3.4	banana	2020/1/2
# 6	c	2.5	orange	2020/1/5

# %%
# 转换成markdown
print(df_csv.to_markdown())
# Out:
# |    |   col1 | col2   |   col3 | col4   | col5                |
# |---:|-------:|:-------|-------:|:-------|:--------------------|
# |  0 |      2 | a      |    1.4 | apple  | 2020-01-01 00:00:00 |
# |  1 |      3 | b      |    3.4 | banana | 2020-01-02 00:00:00 |
# |  2 |      6 | c      |    2.5 | orange | 2020-01-05 00:00:00 |

# %%
# 转换成latex
print(df_csv.style.to_latex())
# Out:
# \begin{tabular}{lrlrll}
#  & col1 & col2 & col3 & col4 & col5 \\
# 0 & 2 & a & 1.400000 & apple & 2020-01-01 \\
# 1 & 3 & b & 3.400000 & banana & 2020-01-02 \\
# 2 & 6 & c & 2.500000 & orange & 2020-01-05 \\
# \end{tabular}

# %% [markdown]
# ## 2.2 基本数据结构

# %% [markdown]
# #### 1.Series

# %%
# 创建Series对象
s = pd.Series(
    data = [100,'a',{'dic1':5}],
    index = pd.Index(['id1',20,'third'],name='my_index'),
    dtype = 'object',
    name = 'my_name'
)
s
# Out:
# my_index
# id1              100
# 20                 a
# third    {'dic1': 5}
# Name: my_name, dtype: object

# %%
# 获取属性内容
s.values
# Out:
# Index(['id1', 20, 'third'], dtype='object', name='my_index')

# %%
s.index
# Out:
# Index(['id1', 20, 'third'], dtype='object', name='my_index')

# %%
s.dtype
# Out:
# dtype('O')

# %%
s.name
# Out:
# 'my_name'

# %%
# 获取序列长度
s.shape
# Out:
# (3,)

# %%
# 索引取值
s['third']
# Out:
# {'dic1': 5}

# %% [markdown]
# #### 2.DataFrame

# %%
df = pd.DataFrame(
    data={
        'col_0':[1,2,3],
        'col_1':list('abc'),
        'col_2':[1.2,2.2,3.2]
    },
    index=[f'row_{i}' for i in range(3)]
)
df
# Out:
#        col_0 col_1  col_2
# row_0      1     a    1.2
# row_1      2     b    2.2
# row_2      3     c    3.2

# %% [markdown]
# ##### 练一练：在上面的df中，如果data字典中'col_0'键对应的不是列表，而是1个索引与df中索引相同的Series，此时会发生什么？如果它的索引和df的索引不一致，又会发生什么？

# %%
# 当索引一致时，序列的值直接对应填入DataFrame。
index = [f'row_{i}' for i in range(3)]
df = pd.DataFrame(
    data={
        'col_0':pd.Series([1,2,3],index=index),
        'col_1':list('abc'),
        'col_2':[1.2,2.2,3.2]
    },
    index=index
)
df
# Out:
#        col_0 col_1  col_2
# row_0      1     a    1.2
# row_1      2     b    2.2
# row_2      3     c    3.2

# %%
# 当索引不一致时且Series中索引值唯一时，当前DataFrame行索引如果在Series中出现，
# 则用Series对应元素填充，否则设为缺失值。
df = pd.DataFrame(
    data={
        'col_0':pd.Series([1,2,3],index=['row_3','row_2','row_1']), # Nan、3、2
        'col_1':list('abc'),
        'col_2':[1.2,2.2,3.2]
    },
    index=index
)
df
# Out:
#        col_0 col_1  col_2
# row_0    NaN     a    1.2
# row_1    3.0     b    2.2
# row_2    2.0     c    3.2

# %%
# 用[col_name]和[col_list]取出相应的列与由多个列组成的新的DataFrame
df['col_0']
# Out:
# row_0    NaN
# row_1    3.0
# row_2    2.0
# Name: col_0, dtype: float64

# %%
# New DataFrame
df[['col_0','col_1']]
# Out:
#        col_0 col_1
# row_0    NaN     a
# row_1    3.0     b
# row_2    2.0     c

# %% [markdown]
# ##### 练一练：df['col_0']和df[['col_0']]二者得到的结果类型有什么区别？

# %%
# 前者是Series，后者是DataFrame
df[['col_0']]
# Out:
#        col_0
# row_0    NaN
# row_1    3.0
# row_2    2.0

# %%
# 把序列转换为列数为1的DataFrame
df['col_0'].to_frame()
# Out:
#        col_0
# row_0      1
# row_1      2
# row_2      3

# %%
# 对DataFrame的行列进行转置
df.T
# Out:
#       row_0 row_1 row_2
# col_0     1     2     3
# col_1     a     b     c
# col_2   1.2   2.2   3.2

# %% [markdown]
# ##### 练一练：给定一个DataFrame，请构造其转置且不得使用“.T”。

# %%
df = pd.DataFrame(data={'A':[1,2,3],'B':[4,5,6]},index=list('abc'))
df_T = pd.DataFrame(df.values.T, index=df.columns, columns=df.index)
df.T.equals(df_T)
# Out:
#    a  b  c
# A  1  2  3
# B  4  5  6

# %% [markdown]
# ##### 修改或删除列

# %%
df = pd.DataFrame(
    data={
        'col_0':pd.Series([1,2,3],index=index), # Nan、3、2
        'col_1':list('abc'),
        'col_2':[1.2,2.2,3.2]
    },
    index=index
)
df["col_0"] = df['col_0'].values[::-1] #颠倒顺序
df["col_2"] *= 2
df["col_3"] = ["apple","banana","cat"] #新增一列
df
# Out:
#        col_0 col_1  col_2   col_3
# row_0      3     a    2.4   apple
# row_1      2     b    4.4  banana
# row_2      1     c    6.4     cat

# %%
# 删除列
df.drop(["col_3"],axis=1)
# Out:
#        col_0 col_1  col_2
# row_0      3     a    2.4
# row_1      2     b    4.4
# row_2      1     c    6.4

# %%
# 删除行
df.drop(["row_1"],axis=0)
# Out:
#        col_0 col_1  col_2  col_3
# row_0      3     a    2.4  apple
# row_2      1     c    6.4    cat

# %% [markdown]
# ## 2.常用基本函数

# %% [markdown]
# #### 1.汇总函数

# %%
import pandas as pd

df = pd.read_csv('data_base/data/learn_pandas.csv')
df.columns
# Out:
# Index(['School', 'Grade', 'Name', 'Gender', 'Height', 'Weight', 'Transfer',
#        'Test_Number', 'Test_Date', 'Time_Record'],
#       dtype='object')

# %%
df = df[df.columns[:7]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   School    200 non-null    object
#  1   Grade     200 non-null    object
#  2   Name      200 non-null    object
#  3   Gender    200 non-null    object
#  4   Height    183 non-null    float64
#  5   Weight    189 non-null    float64
#  6   Transfer  188 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#            Height      Weight
# count  183.000000  189.000000
# mean   163.218033   55.015873
# std      8.608879   12.824294
# min    145.400000   34.000000
# 25%    157.150000   46.000000
# 50%    161.900000   51.000000
# 75%    167.500000   65.000000
# max    193.900000   89.000000

# %% [markdown]
# #### 2.特征统计函数

# %%
df_demo = df[['Height','Weight']]
df_demo.max()
# Out:
# Height    193.9
# Weight     89.0
# dtype: float64

# %%
df_demo.mean()
# Out:
# Height    163.218033
# Weight     55.015873
# dtype: float64

# %%
df_demo.quantile(0.75)
# Out:
# Height    167.5
# Weight     65.0
# Name: 0.75, dtype: float64

# %%
df_demo.idxmax() #最大值对应的索引
# Out:
# Height    193
# Weight      2
# dtype: int64

# %% [markdown]
# ##### 练一练：身体质量指数BMI的计算方式是体重（单位为kg）除以身高（单位为m）的平方，请找出具有最高BMI指数对应同学的姓名。

# %%
df.T[(df.Weight / (df.Height / 100 ) ** 2).idxmax()]['Name']
# Out:
# 'Chengpeng Zhou'

# %% [markdown]
# #### 3.频次函数

# %%
df.School.unique()
df['School'].nunique()
# Out:
# 4

# %%
df['School'].value_counts()
# Out:
# School
# D    69
# A    57
# C    40
# B    34
# Name: count, dtype: int64

# %%
df['School'].value_counts(normalize=True)
# Out:
# School
# D    0.345
# A    0.285
# C    0.200
# B    0.170
# Name: proportion, dtype: float64

# %%
# 观察多个列组合的唯一值
df_demo = df[['Gender','Transfer','Name']]
df_demo.drop_duplicates(['Gender','Name'])
# Out:
#      Gender Transfer            Name
# 0    Female        N    Gaopeng Yang
# 1      Male        N  Changqiang You
# 2      Male        N         Mei Sun
# 3    Female        N    Xiaojuan Sun
# 4      Male        N     Gaojuan You
# ..      ...      ...             ...
# 194  Female      NaN     Yanmei Qian
# 196  Female        N         Li Zhao
# 197  Female        N  Chengqiang Chu
# 198    Male        N   Chengmei Shen
# 199    Male        N     Chunpeng Lv
#
# [181 rows x 3 columns]

# %%
# 关键参数keep
df_demo.drop_duplicates(['Gender','Transfer'],keep='last')
# Out:
#      Gender Transfer            Name
# 147    Male      NaN        Juan You
# 150    Male        Y   Chengpeng You
# 169  Female        Y   Chengquan Qin
# 194  Female      NaN     Yanmei Qian
# 197  Female        N  Chengqiang Chu
# 199    Male        N     Chunpeng Lv

# %%
# keep设为False代表只出现过一次的行
df_demo.drop_duplicates(['Name','Gender'],keep=False).head()
# Out:
#    Gender Transfer            Name
# 0  Female        N    Gaopeng Yang
# 1    Male        N  Changqiang You
# 2    Male        N         Mei Sun
# 4    Male        N     Gaojuan You
# 5  Female        N     Xiaoli Qian

# %%
# duplicated()查重
df_demo.duplicated(['Gender','Transfer'])
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 195     True
# 196     True
# 197     True
# 198     True
# 199     True
# Length: 200, dtype: bool

# %%
df['School'].duplicated().head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: School, dtype: bool
